# %%
# !pip install "pymongo[srv]==3.12"
# Out:
# ...
#      ---------------------------------------- 0.0/818.6 kB ? eta -:--:--
#      -------------------------------------- 818.6/818.6 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pymongo: filename=pymongo-3.12.0-cp312-cp312-win_amd64.whl size=359274 sha256=2f1c33fda0a20042e0c2fe648204ca208e2a55da28455ea6986b107cf7ab8667
#   Stored in directory: c:\users\isabel\appdata\local\pip\cache\wheels\4e\49\39\293a3914a095e62eeefc25b88f9f5ace620fc19d9b1883762b
# Successfully built pymongo
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://test:test@cluster0.8laswgd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import yfinance as yf 

lmt_finanzas = {
    "ticker": "LMT",
    "nombre": "Lockheed Martin Corporation",
    "sector": "Aeroespacial y Defensa",
    "ultimo_cierre": 450.75,  # Precio en USD
    "capitalizacion_mercado": 112.5e9,  # 112.5 mil millones de USD
    "ingresos_anuales": 67.0e9,         # 67 mil millones de USD
    "beneficio_neto": 6.2e9,            # 6.2 mil millones de USD
    "eps": 24.50,                       # Ganancias por acción
    "dividend_yield": 0.028,            # 2.8%
    "ratio_per": 16.8,
    "deuda_total": 15.8e9,
    "flujo_efectivo_operativo": 8.1e9
}

amzn_finanzas = {
    "ticker": "AMZN",
    "nombre": "Amazon.com, Inc.",
    "sector": "Comercio Electrónico y Cloud Computing",
    "ultimo_cierre": 175.50,  # Precio en USD (ajustado por splits)
    "capitalizacion_mercado": 1.8e12,    # 1.8 billones de USD
    "ingresos_anuales": 574.8e9,         # 574.8 mil millones de USD
    "beneficio_neto": 30.4e9,            # 30.4 mil millones de USD
    "eps": 2.90,
    "dividend_yield": 0.00,              # No paga dividendos
    "ratio_per": 60.5,
    "deuda_total": 135.4e9,
    "flujo_efectivo_operativo": 84.9e9,
    "crecimiento_ingresos_anual": 0.12   # 12%
}

pltr_finanzas = {
    "ticker": "PLTR",
    "nombre": "Palantir Technologies Inc.",
    "sector": "Software y Servicios de Analítica de Datos",
    "ultimo_cierre": 21.80,   # Precio en USD
    "capitalizacion_mercado": 45.2e9,    # 45.2 mil millones de USD
    "ingresos_anuales": 2.2e9,           # 2.2 mil millones de USD
    "beneficio_neto": 0.21e9,            # 210 millones de USD (beneficio reciente)
    "eps": 0.09,
    "dividend_yield": 0.00,              # No paga dividendos
    "ratio_per": 220.0,                  # Muy alto (común en empresas de crecimiento)
    "deuda_total": 0.25e9,               # Muy poca deuda
    "flujo_efectivo_operativo": 0.71e9,
    "crecimiento_ingresos_anual": 0.21   # 21%
}

# %%
db = client.test
db.name
db.my_collection

db.my_collection.insert_one(lmt_finanzas)
db.my_collection.insert_one(amzn_finanzas)
db.my_collection.insert_one(pltr_finanzas)
x = db.my_collection.find_one()

# %%
import pandas as pd
print(x)
# Out:
# {'_id': ObjectId('68d838a823e3bf8b5a4c31d6'), 'ticker': 'LMT', 'nombre': 'Lockheed Martin Corporation', 'sector': 'Aeroespacial y Defensa', 'ultimo_cierre': 450.75, 'capitalizacion_mercado': 112500000000.0, 'ingresos_anuales': 67000000000.0, 'beneficio_neto': 6200000000.0, 'eps': 24.5, 'dividend_yield': 0.028, 'ratio_per': 16.8, 'deuda_total': 15800000000.0, 'flujo_efectivo_operativo': 8100000000.0, 'empleados': '1000'}

# %%
print(x)
# Out:
# {'documents': [{'_id': 65, 'name': 'A large sunny bedroom', 'accommodates': 1, 'room_type': 'Private room', 'pricePerNight': 35, 'host_name': 'Ehssan', 'host_email': 'ehssan@gmail.com'}, {'_id': 94, 'name': 'Cozy bedroom Sagrada Familia', 'accommodates': 2, 'room_type': 'Private room', 'pricePerNight': 20, 'host_name': 'Rapha', 'host_email': 'rapha@gmail.com'}, {'_id': 10, 'name': 'Modern Spacious 1 Bedroom Loft', 'accommodates': 4, 'room_type': 'Entire home/apt', 'pricePerNight': 50, 'host_name': 'Konstantin', 'host_email': 'konstantin@gmail.com'}, {'_id': 22, 'name': 'Easy 1 Bedroom in Chelsea', 'accommodates': 2, 'room_type': 'Entire home/apt', 'pricePerNight': 145, 'host_name': 'Scott', 'host_email': 'scott@gmail.com'}, {'_id': 31, 'name': '2 bedroom Upper east side', 'accommodates': 5, 'room_type': 'Entire home/apt', 'pricePerNight': 275, 'host_name': 'Chelsea', 'host_email': 'chelsea@gmail.com'}, {'_id': 34, 'name': 'A bedroom far away from home', 'accommodates': 2, 'room_type'
# ...

# %%
x.keys()
# Out:
# dict_keys(['documents'])

# %%
import numpy as np

y= list(x.values()) 
y[0][0]
# Out:
# {'_id': 65,
#  'name': 'A large sunny bedroom',
#  'accommodates': 1,
#  'room_type': 'Private room',
#  'pricePerNight': 35,
#  'host_name': 'Ehssan',
#  'host_email': 'ehssan@gmail.com'}

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://test:test@cluster0.8laswgd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from datetime import datetime, timedelta

# Current date and time
current_time = datetime.now()

amzn = {'ticker': 'AMZN',
  'nombre': 'Amazon.com, Inc.',
  'sector': 'Consumer Cyclical',
  'industria': 'Internet Retail',
  'precio_actual': 214.75999450683594,
  'precio_apertura': 213.8000030517578,
  'maximo_dia': 215.66000366210938,
  'minimo_dia': 213.58999633789062,
  'volumen': 15058979,
  'rendimiento_diario': 0.81,
  'rendimiento_periodo': -5.65,
  'market_cap': 2290823200768,
  'pe_ratio': 32.743904,
  'forward_pe': 34.92683,
  'pb_ratio': 6.860209,
  'ps_ratio': 3.418945,
  'dividend_yield': 0.0,
  'roe': 0.2477,
  'margen_beneficio': 0.105399996,
  'beta': 1.281,
  'fecha_actualizacion': current_time,
  'ultimo_cierre': 214.75999450683594}
lmt = {'ticker': 'LMT',
  'nombre': 'Lockheed Martin Corporation',
  'sector': 'Industrials',
  'industria': 'Aerospace & Defense',
  'precio_actual': 503.0,
  'precio_apertura': 496.42999267578125,
  'maximo_dia': 503.2300109863281,
  'minimo_dia': 496.42999267578125,
  'volumen': 474306,
  'rendimiento_diario': 1.59,
  'rendimiento_periodo': 4.71,
  'market_cap': 117432926208,
  'pe_ratio': 28.21088,
  'forward_pe': 17.893988,
  'pb_ratio': 21.878126,
  'ps_ratio': 1.6345543,
  'dividend_yield': 2.79,
  'roe': 0.73056,
  'margen_beneficio': 0.058520004,
  'beta': 0.274,
  'fecha_actualizacion': current_time,
  'ultimo_cierre': 503.0}

# %%
db = client.financials
db.name
db.my_collection

db.my_collection.insert_one(amzn)

# %%
db = client[DB_NAME]
collection = db['stock_kpis']
