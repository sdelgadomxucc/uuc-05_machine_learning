# %%
import mysql.connector

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro"
)
mycursor = mydb.cursor()
mycursor.execute("create database coffee2")

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro"
)
mycursor = mydb.cursor()
mycursor.execute("show databases")

for x in mycursor:
    print(x)
# Out:
# ('Artists',)
# ('books',)
# ('coffee',)
# ('coffee1',)
# ('coffee2',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('writers',)

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE client (name VARCHAR(255), address VARCHAR(255), Phone int)")

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)
mycursor = mydb.cursor()
mycursor.execute("show tables")
for x in mycursor:
    print(x)
# Out:
# ('client',)

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE customers (id INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(255), address VARCHAR(255))")

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

name = input("Enter Name:")
address = input("Enter Address:")

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = (name,address)
mycursor.execute(sql, val)

mydb.commit()
print(mycursor.rowcount, "record inserted.")
# Out:
# Enter Name:Cesar
# Enter Address:CDMX
# 1 record inserted.

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
  ('John', 'California 2'),
  ('Juliette', 'Paris 4'),
  ('Varun', 'Ontario'),
  ('Franz', 'Berlin'),
  ('Giulio', 'Rome'),
]

mycursor.executemany(sql, val)

mydb.commit()
print(mycursor.rowcount, "record inserted.")
# Out:
# 5 record inserted.

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

name = input("Enter Name:")
address = input("Enter Address:")

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = (name,address)

mycursor.execute(sql, val)

mydb.commit()
print("1 record inserted, ID:", mycursor.lastrowid)
# Out:
# Enter Name:David
# Enter Address:Barcelona
# 1 record inserted, ID: 7

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Cesar', 'CDMX')
# (2, 'John', 'California 2')
# (3, 'Juliette', 'Paris 4')
# (4, 'Varun', 'Ontario')
# (5, 'Franz', 'Berlin')
# (6, 'Giulio', 'Rome')
# (7, 'David', 'Barcelona')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT name, address FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('Cesar', 'CDMX')
# ('John', 'California 2')
# ('Juliette', 'Paris 4')
# ('Varun', 'Ontario')
# ('Franz', 'Berlin')
# ('Giulio', 'Rome')
# ('David', 'Barcelona')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT name, address FROM customers")

myresult = mycursor.fetchone()

print(myresult)
# Out:
# ('Cesar', 'CDMX')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()
sql = "SELECT * FROM customers WHERE address ='Varun'"
mycursor.execute(sql)

myresult = mycursor.fetchall()
for x in myresult:
    print(x)

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()
sql = "SELECT * FROM customers WHERE address = %s"
adr = ("Ontario", )

mycursor.execute(sql, adr)
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (4, 'Varun', 'Ontario')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = %s"
adr = ("Ontario", )

mycursor.execute(sql, adr)
mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()
sql = "UPDATE customers SET address = 'Hong Kong' WHERE address = 'CDMX'"
mycursor.execute(sql)
mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee"
)
mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM customers LIMIT 5")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Cesar', 'CDMX')
# (2, 'John', 'California 2')
# (4, 'Varun', 'Detroit')
# (5, 'Franz', 'Berlin')
# (6, 'Giulio', 'Rome')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee"
)
mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM customers LIMIT 5 OFFSET 2")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (4, 'Varun', 'Detroit')
# (5, 'Franz', 'Berlin')
# (6, 'Giulio', 'Rome')
# (7, 'David', 'Barcelona')

# %% [markdown]
# ## Join

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE product (id int, prodname VARCHAR(255))")

sql = "INSERT INTO product (id, prodname) VALUES (%s, %s)"
val = [
  ('2', 'Black'),
  ('3', 'Latte'),
  ('4', 'Americano'),
  ('5', 'Cold Brew'),
  ('6', 'Flat'),
]

mycursor.executemany(sql, val)

mydb.commit()
print(mycursor.rowcount, "record inserted.")
# Out:
# 5 record inserted.

# %%
import mysql.connector 
 
mydb = mysql.connector.connect( 
    host='localhost', 
    user='root', 
    password='Perfeligro', 
    database='coffee2' 
) 
 
mycursor = mydb.cursor() 
 
sql = "DROP TABLE product;" 
 
mycursor.execute(sql)

# %% [markdown]
# ### Inner Join

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM customers JOIN product ON customers.id = product.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Cesar', 'Hong Kong', 1, 'Black')
# (2, 'John', 'California 2', 2, 'Latte')
# (3, 'Juliette', 'Paris 4', 3, 'Americano')
# (5, 'Franz', 'Berlin', 5, 'Flat')

# %% [markdown]
# ### Select

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT customers.id,customers.name,customers.address,product.prodname \
       FROM customers JOIN product ON customers.id = product.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (2, 'John', 'California 2', 'Black')
# (3, 'Juliette', 'Paris 4', 'Latte')
# (5, 'Franz', 'Berlin', 'Cold Brew')
# (6, 'Giulio', 'Rome', 'Flat')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT customers.id,customers.name,customers.address,product.prodname \
       FROM customers INNER JOIN product ON customers.id = product.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (2, 'John', 'California 2', 'Black')
# (3, 'Juliette', 'Paris 4', 'Latte')
# (5, 'Franz', 'Berlin', 'Cold Brew')
# (6, 'Giulio', 'Rome', 'Flat')

# %% [markdown]
# ## Left Join

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT customers.id,customers.name,customers.address,product.prodname \
       FROM customers LEFT JOIN product ON customers.id = product.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Cesar', 'Hong Kong', None)
# (2, 'John', 'California 2', 'Black')
# (3, 'Juliette', 'Paris 4', 'Latte')
# (5, 'Franz', 'Berlin', 'Cold Brew')
# (6, 'Giulio', 'Rome', 'Flat')
# (7, 'David', 'Barcelona', None)

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT customers.id,customers.name,customers.address,product.prodname \
       FROM customers RIGHT JOIN product ON customers.id = product.id"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (2, 'John', 'California 2', 'Black')
# (3, 'Juliette', 'Paris 4', 'Latte')
# (None, None, None, 'Americano')
# (5, 'Franz', 'Berlin', 'Cold Brew')
# (6, 'Giulio', 'Rome', 'Flat')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Perfeligro",
  database="coffee2"
)

mycursor = mydb.cursor()

sql = "SELECT * from customers as t1 LEFT JOIN product as t2 ON t1.id = t2.id \
 UNION SELECT * from customers as t1 RIGHT JOIN product as t2 ON t1.id = t2.id "

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Cesar', 'Hong Kong', None, None)
# (2, 'John', 'California 2', 2, 'Black')
# (3, 'Juliette', 'Paris 4', 3, 'Latte')
# (5, 'Franz', 'Berlin', 5, 'Cold Brew')
# (6, 'Giulio', 'Rome', 6, 'Flat')
# (7, 'David', 'Barcelona', None, None)
# (None, None, None, 4, 'Americano')

# %%
import pandas as pd

from_database = []

for result in myresult:
  result = list(result)
  from_database.append(result)


columns = ["Id", "Customer", "City", "Product", "Prodname"]
df = pd.DataFrame(from_database, columns=columns)

# %%
display(df)
# Out:
#     Id  Customer          City  Product   Prodname
# 0  1.0     Cesar     Hong Kong      NaN       None
# 1  2.0      John  California 2      2.0      Black
# 2  3.0  Juliette       Paris 4      3.0      Latte
# 3  5.0     Franz        Berlin      5.0  Cold Brew
# 4  6.0    Giulio          Rome      6.0       Flat
# 5  7.0     David     Barcelona      NaN       None
# 6  NaN      None          None      4.0  Americano
